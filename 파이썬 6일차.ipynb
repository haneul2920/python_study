# %%
# 문제 : 5칙연산을 수행하는 함수를 만들어주세요.

# plus 함수 구현
def plus(a,b):
  return a+b

print("3 더하기 5는 {} 입니다.".format(plus(3, 5)))
# 출력 => 3 더하기 5는 8 입니다.

# plus_3_nums 함수 구현
def plus_3_nums(a,b,c):
  return a+b+c

print("3 더하기 5 더하기 7은 {} 입니다.".format(plus_3_nums(3, 5, 7)))
# 출력 => 3 더하기 5 더하기 7은 15 입니다.

# minus 함수 구현
def minus(a,b):
  return a-b

print("10 빼기 5 는 {} 입니다.".format(minus(10, 5)))
# 출력 => 10 빼기 5 는 5 입니다.

# multiply 함수 구현

def multiply(a,b):
  return a*b

print("10 곱하기 5 는 {} 입니다.".format(multiply(10, 5)))
# 출력 => 10 곱하기 5 는 50 입니다.

# mod 함수 구현
def mod(a,b):
  return int(a/b)

print("4를 3으로 나눈 나머지는 {} 입니다.".format(mod(4, 3)))
# 출력 => 4를 3으로 나눈 나머지는 1 입니다.

# div 함수 구현
def div(a,b):
  return a/b

print("4를 3으로 나눈 몫은 {0:.0f} 입니다.".format(div(4, 3)))
# 출력 => 4를 3으로 나눈 몫은 1 입니다.

# div2 함수 구현
def div2(a,b):
  return a/b

print("4를 3으로 나눈 결과는 {} 입니다.".format(div2(4, 3)))
# 출력 => 4를 3으로 나눈 결과는 1.3333333333333333 입니다.
# Out:
# 3 더하기 5는 8 입니다.
# 3 더하기 5 더하기 7은 15 입니다.
# 10 빼기 5 는 5 입니다.
# 10 곱하기 5 는 50 입니다.
# 4를 3으로 나눈 나머지는 1 입니다.
# 4를 3으로 나눈 몫은 1 입니다.
# 4를 3으로 나눈 결과는 1.3333333333333333 입니다.

# %%
# 문제 : 온도단위 섭씨를, 화씨로 바꿔주는, 함수 c_to_f 를 구현해주세요.
# 조건 : 공식 = 섭씨온도 * (9 / 5) + 32 => 화씨온도

def c_to_f(c):
  f = 0 # 구현
  c = c*(9/5)+32
  f=c
  return f

print(c_to_f(10))
# 출력 => 50.0
print(c_to_f(20))
# 출력 => 68.0
print(c_to_f(30))
# 출력 => 86.0
# Out:
# 50.0
# 68.0
# 86.0

# %%
# 문제 : 입력받은 정수가 짝수인지 아닌지 판별해주는 함수 구현

def is_even(a):
  if a % 2 == 0:
    return "짝수입니다."
  return "홀수입니다."

print("10은(는) 짝수인가요? : {}\n".format(is_even(10)));
print("11은(는) 짝수인가요? : {}\n".format(is_even(11)));
# Out:
# 10은(는) 짝수인가요? : 짝수입니다.
#
# 11은(는) 짝수인가요? : 홀수입니다.

# %%
# 문제 : 입력받은 정수가 3의 배수인지 알려주는 함수 구현

def is_3_multiple(a):
  if a % 3 == 0:
    return "true"
  return "false"

print("10은(는) 3의 배수인가요? : {}\n".format(is_3_multiple(10)))
print("12은(는) 3의 배수인가요? : {}\n".format(is_3_multiple(12)))
# Out:
# 10은(는) 3의 배수인가요? : false
#
# 12은(는) 3의 배수인가요? : true

# %%
#문제 : 입력받은 정수가 100보다 큰지 알려주는 함수 구현

def is_bigger_than_100(a):
  if a > 100:
    return "true"
  return "false"

print("128은(는) 100보다 큽니다. : {}\n".format(is_bigger_than_100(128)));
print("28은(는) 100보다 큽니다. : {}\n".format(is_bigger_than_100(28)));
# Out:
# 128은(는) 100보다 큽니다. : true
#
# 28은(는) 100보다 큽니다. : false

# %%
# 문제 : 입력받은 정수의 모든 약수의 합을 리턴하는 함수를 구현해주세요.

def get_divisors_sum(num):
  s = 0
  i = 1

  ''' 구현 '''
  while i <= num:
    if num % i == 0:
      s += i
    i += 1

  return s

s = get_divisors_sum(1000)

print("정수 1000의 약수의 합 : {}".format(s))
# 출력 => 정수 1000의 약수의 합 : 2340
# Out:
# 정수 1000의 약수의 합 : 2340

# %%
# 문제 : 입력받은 정수가 소수인지 아닌지 알려주는 함수를 구현해주세요.
# 소수 : 1과 자기 자신만을 약수로 가지는 수

def is_prime_number(a):
  if a % 2 != 0:
    return "True"
  return "False"

def is_prime_number2(a):
  if a == 1:
    return False
  j = 0
  i = 2
  while i < a:
    if a % i == 0:
      a = j
      return False
  return True


print("3은 소수입니다. : {}".format(is_prime_number(3)))
print("4은 소수입니다. : {}".format(is_prime_number(4)))
print("1000은 소수입니다. : {}".format(is_prime_number(1000)))
# Out:
# 3은 소수입니다. : True
# 4은 소수입니다. : False
# 1000은 소수입니다. : False

# %%
# 문제 - 1부터 1000사이에 존재하는 소수들의 개수를 출력해주세요.(개념 : 함수, 반복문, 리턴)
def is_prime_number2(a):
  if a == 1:
    return False

  i = 2
  while i < a:
    if a % i == 0:
      return False
    i += 1
  return True


def cnt_prime_num(num):
  i = 1
  count = 0
  while i <= num:
    if is_prime_number2(i):
      count += 1
    i += 1
  return count

print(cnt_prime_num(1000))
# Out:
# 168

# %%
#문제 : 입력받은 숫자가 10이라고 할때 1부터 10 사이에 존재하는 모든 소수를 출력하는 함수 구현

def print_1_to_n_prime_numbers(num):
  i = 1
  while i <= num:
    if is_prime_number2(i):
      print(i)
    i += 1


print_1_to_n_prime_numbers(10)
# Out:
# 2
# 3
# 5
# 7

# %%
# 문제 : 1부터 n 사이의 수 중에서 소수의 개수 반환하는 함수 `get_1_to_n_prime_numbers_count` 를 구현해주세요.


#1부터 n 사이의 수 중에서 소수의 개수 반환하는 함수

def is_prime_number2(a):
  if a == 1:
    return False

  i = 2
  while i < a:
    if a % i == 0:
      return False
    i += 1
  return True


def get_1_to_n_prime_numbers_count(num):
  i = 1
  count = 0
  while i <= num:
    if is_prime_number2(i):
      count += 1
    i += 1
  return count

print("1부터 {}사이에 존재하는 소수의 개수 : {}개\n".format(1000,get_1_to_n_prime_numbers_count(1000)))
  # 출력 => 1부터 1000사이에 존재하는 소수의 개수 : 168개


print("1부터 {}사이에 존재하는 소수의 개수 : {}개\n".format(2000,get_1_to_n_prime_numbers_count(2000)))
  # 출력 => 1부터 2000사이에 존재하는 소수의 개수 : 303개
# Out:
# 1부터 1000사이에 존재하는 소수의 개수 : 168개
#
# 1부터 2000사이에 존재하는 소수의 개수 : 303개

# %%
# 문제 : 1부터 n 사이의 수 중에서 소수의 합을 반환하는 함수 `get_1_to_n_prime_numbers_sum` 를 구현해주세요.


# 1부터 n 사이의 수 중에서 소수의 합 반환하는 함수
def is_prime_number2(a):
  if a == 1:
    return False

  i = 2
  while i < a:
    if a % i == 0:
      return False
    i += 1
  return True

def get_1_to_n_prime_numbers_sum(n):
  # 구현
  sum = 0
  i = 1
  while i <= n:
    if is_prime_number2(i):
      sum += i
    i +=1
  return sum




print("1부터 {}사이에 존재하는 소수의 개수 : {}개\n".format(1000 , get_1_to_n_prime_numbers_sum(1000)))
  # 출력 => 1부터 1000사이에 존재하는 소수의 합 : 76127


print("1부터 {}사이에 존재하는 소수의 개수 : {}개\n".format(2000, get_1_to_n_prime_numbers_sum(2000)))
 # 출력 => 1부터 2000사이에 존재하는 소수의 합 : 277050
# Out:
# 1부터 1000사이에 존재하는 소수의 개수 : 76127개
#
# 1부터 2000사이에 존재하는 소수의 개수 : 277050개
