# %%
# 모듈 : import
# 라이브러리

# 게임
# 시작 종료
# 캐릭터 이동,공격,방어.. 등등
# 총알 날아가는 표현

# <주피터 노트북>
# 파이썬 파일을 실행시켜주는 프로그램

# 주피터 노트북 + 부가기능 = 아나콘다
# feat) visual studio code, colab

# -FPS(frame per sec)
# 초당 프레임
# 프레임 : 컴퓨터가 송신하는 화면


# =====파이게임의 틀=====
# pip install pygame
import pygame

# 1. 초기화 -> 변수의 선언
# 2. 게임 화면 설정 -> 고정값
# 3. 게임 내에서의 설정 -> 변수
# 4. 메인 이벤트
#  -1. FPS(Frame per sec) 설정
#  -2. 입력(키보드,마우스)의 감지 -> 활용
#  -3. 입력에 따른 변화, 시간에 따른 변화
#  -4. 전사작업(그리기)
#  -5. 업데이트
# 5. 종료(x버튼, game over)

# %%
import random

random.random() # 0부터 1 사이 난수
random.randrange(1,8) #a부터 b사이 난수

a = ['a','b','c','d','c']
random.shuffle(a)
a
# Out:
# ['c', 'd', 'a', 'b', 'c']

# %%
import pygame

# 1. 초기화 -> 변수의 선언
pygame.init()

# 2. 게임 화면 설정 -> 고정값
screen = pygame.display.set_mode([600,800])
pygame.display.set_caption("PY_Galara")

# 3. 게임 내에서의 설정 -> 변수
clock = pygame.time.Clock()
color1 = (83,104,154)

hero = pygame.image.load('C:/Users/admin/Desktop/pygame/spaceship.png')
hero = pygame.transform.scale(hero,(100,100))
# 4. 메인 이벤트
system = 0

while system == 0:

#  -1. FPS(Frame per sec) 설정
    clock.tick(2)

#  -2. 입력(키보드,마우스)의 감지 -> 활용
    for event in pygame.event.get():
        # print("평상시 : ",event)
        if event.type == pygame.QUIT:
            systme = 1

#  -3. 입력에 따른 변화, 시간에 따른 변화

#  -4. 전사작업(그리기)
    screen.fill(color1)
    screen.blit(hero, (250,680))
#  -5. 업데이트
    pygame.display.flip()
# 5. 종료(x버튼, game over)
pygame.QUIT()
