# %%
# 주석 : # 이후 내용들은 코드에 해당하지 않게 하는 문법. 코드에 대한 설명을 쓴다.
# ctrl + / : 주석 단축키
# 출력문

print(출력하고자 하는 내용)

print("") # 문자 데이터를 출력
print() # 숫자데이터를 출력

# %%
print('hello world!!')
# Out:
# hello world!!

# %%
print("안녕하세요!")
# Out:
# 안녕하세요!

# %%
print(10)
# Out:
# 10

# %%
# 문제 : `안녕하세요.`를 10번 출력해주세요.
# alt + shift + 위/아래 화살표 : 복붙

print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
print("안녕하세요.")
# Out:
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.

# %%
# 문제 : `안녕하세요.`를 10번 출력해주세요.
# 조건 : print는 딱 한번만 사용 가능
print("안녕하세요.\n" * 10)
# Out:
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.
# 안녕하세요.

# %%
# 출력문 뉴라인 : 문자\n

# 구글 검색 -> 어떻게 사용하는거지? -> 적용

# 뉴라인(\n)은 문자데이터 내부에서 줄바꿈을 해준다.
print("안\n녕\n하\n세\n요")
# Out:
# 안
# 녕
# 하
# 세
# 요
